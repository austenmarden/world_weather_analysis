# %%
# %matplotlib inline

# %%
#add Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
import timeit
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
#Empty city_data list
city_data = []
print('Log Start')
print("-----------------------------")

#create counters
record_count = 1
set_count = 1
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather": weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Log Start
# -----------------------------
# Processing Record 1 of Set 1 | waddan
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | souillac
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | cherskiy
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | lagoa
# Processing Record 10 of Set 1 | santiago del estero
# Processing Record 11 of Set 1 | kloulklubed
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | bandar-e lengeh
# Processing Record 14 of Set 1 | qaqortoq
# Processing Record 15 of Set 1 | lebu
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | bulungu
# Processing Record 19 of Set 1 | port-cartier
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | arlit
# Processing Record 23 of Set 1 | north bend
# Processing Record 24 of Set 1 | college
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | gushikawa
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | bambous virieux
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | shaoguan
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | ponta do sol
# Processing Record 47 of Set 1 | korla
# Processing Record 48 of Set 1 | airai
# Processing Record 49 of Set 1 | fayaoue
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | praya
# Processing Record 2 of Set 2 | cururupu
# Processing Record 3 of Set 2 | kavieng
# Processing Record 4 of Set 2 | puerto quijarro
# Processing Record 5 of Set 2 | liku
# Processing Record 6 of Set 2 | gat
# Processing Record 7 of Set 2 | trairi
# Processing Record 8 of Set 2 | thinadhoo
# Processing Record 9 of Set 2 | sitka
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | bardiyah
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | ginir
# Processing Record 14 of Set 2 | tuatapere
# Processing Record 15 of Set 2 | kerchevskiy
# Processing Record 16 of Set 2 | zhigansk
# Processing Record 17 of Set 2 | grand gaube
# Processing Record 18 of Set 2 | dingle
# Processing Record 19 of Set 2 | biloela
# Processing Record 20 of Set 2 | straumen
# Processing Record 21 of Set 2 | pailon
# Processing Record 22 of Set 2 | gizo
# Processing Record 23 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | mount pleasant
# Processing Record 27 of Set 2 | bereda
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | nancha
# Processing Record 30 of Set 2 | stokmarknes
# Processing Record 31 of Set 2 | upernavik
# Processing Record 32 of Set 2 | aklavik
# Processing Record 33 of Set 2 | northam
# Processing Record 34 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | santa rosa
# Processing Record 37 of Set 2 | zhigalovo
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | islamkot
# Processing Record 41 of Set 2 | saskylakh
# Processing Record 42 of Set 2 | kahului
# Processing Record 43 of Set 2 | eregli
# Processing Record 44 of Set 2 | takab
# Processing Record 45 of Set 2 | narrabri
# Processing Record 46 of Set 2 | faanui
# Processing Record 47 of Set 2 | ilulissat
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | kayerkan
# Processing Record 50 of Set 2 | altamont
# Processing Record 1 of Set 3 | saint george
# Processing Record 2 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 3 | karasjok
# Processing Record 4 of Set 3 | muisne
# Processing Record 5 of Set 3 | tunghsiao
# City not found. Skipping...
# Processing Record 6 of Set 3 | akyab
# Processing Record 7 of Set 3 | dianopolis
# City not found. Skipping...
# Processing Record 8 of Set 3 | rabaul
# Processing Record 9 of Set 3 | carutapera
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | kodinar
# Processing Record 12 of Set 3 | oksfjord
# Processing Record 13 of Set 3 | khuzhir
# Processing Record 14 of Set 3 | erenhot
# Processing Record 15 of Set 3 | axim
# Processing Record 16 of Set 3 | sechura
# Processing Record 17 of Set 3 | puerto escondido
# Processing Record 18 of Set 3 | san francisco
# Processing Record 19 of Set 3 | taltal
# Processing Record 20 of Set 3 | vagur
# Processing Record 21 of Set 3 | dukat
# Processing Record 22 of Set 3 | mount gambier
# Processing Record 23 of Set 3 | nemuro
# Processing Record 24 of Set 3 | olafsvik
# Processing Record 25 of Set 3 | westport
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | jurmala
# Processing Record 28 of Set 3 | sakaiminato
# Processing Record 29 of Set 3 | constitucion
# Processing Record 30 of Set 3 | itarema
# Processing Record 31 of Set 3 | taoudenni
# Processing Record 32 of Set 3 | tiksi
# Processing Record 33 of Set 3 | sabang
# Processing Record 34 of Set 3 | pontes e lacerda
# Processing Record 35 of Set 3 | rocha
# Processing Record 36 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 3 | weirton
# Processing Record 38 of Set 3 | spokoynaya
# Processing Record 39 of Set 3 | conceicao do araguaia
# Processing Record 40 of Set 3 | kaitangata
# Processing Record 41 of Set 3 | neiafu
# Processing Record 42 of Set 3 | hamilton
# Processing Record 43 of Set 3 | kasongo-lunda
# Processing Record 44 of Set 3 | victoria
# Processing Record 45 of Set 3 | moose factory
# Processing Record 46 of Set 3 | lakhdenpokhya
# Processing Record 47 of Set 3 | bowling green
# Processing Record 48 of Set 3 | port augusta
# Processing Record 49 of Set 3 | kitui
# Processing Record 50 of Set 3 | alofi
# Processing Record 1 of Set 4 | lantana
# Processing Record 2 of Set 4 | santa cruz
# Processing Record 3 of Set 4 | port macquarie
# Processing Record 4 of Set 4 | paracuru
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | vestmannaeyjar
# Processing Record 7 of Set 4 | luderitz
# Processing Record 8 of Set 4 | avarua
# Processing Record 9 of Set 4 | shu
# Processing Record 10 of Set 4 | faya
# Processing Record 11 of Set 4 | mahibadhoo
# Processing Record 12 of Set 4 | vila franca do campo
# Processing Record 13 of Set 4 | quime
# Processing Record 14 of Set 4 | margate
# Processing Record 15 of Set 4 | sao joao da barra
# Processing Record 16 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 4 | troitsko-pechorsk
# Processing Record 18 of Set 4 | aksha
# Processing Record 19 of Set 4 | el reno
# Processing Record 20 of Set 4 | sao filipe
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | bluff
# Processing Record 23 of Set 4 | araouane
# Processing Record 24 of Set 4 | paragominas
# Processing Record 25 of Set 4 | krotovka
# Processing Record 26 of Set 4 | half moon bay
# Processing Record 27 of Set 4 | kedrovyy
# Processing Record 28 of Set 4 | bathsheba
# Processing Record 29 of Set 4 | naples
# Processing Record 30 of Set 4 | kropotkin
# Processing Record 31 of Set 4 | jiuquan
# Processing Record 32 of Set 4 | marsabit
# Processing Record 33 of Set 4 | nikolskoye
# Processing Record 34 of Set 4 | saint-philippe
# Processing Record 35 of Set 4 | pop
# Processing Record 36 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 4 | new norfolk
# Processing Record 38 of Set 4 | carnarvon
# Processing Record 39 of Set 4 | seydi
# Processing Record 40 of Set 4 | guerrero negro
# Processing Record 41 of Set 4 | hilo
# Processing Record 42 of Set 4 | kodiak
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | the valley
# Processing Record 45 of Set 4 | adrar
# Processing Record 46 of Set 4 | east london
# Processing Record 47 of Set 4 | barrow
# Processing Record 48 of Set 4 | tilichiki
# Processing Record 49 of Set 4 | praia
# Processing Record 50 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 5 | pogar
# Processing Record 2 of Set 5 | liseleje
# Processing Record 3 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 4 of Set 5 | florianopolis
# Processing Record 5 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | suluq
# Processing Record 7 of Set 5 | saint-pierre
# Processing Record 8 of Set 5 | saldanha
# Processing Record 9 of Set 5 | san quintin
# Processing Record 10 of Set 5 | ostroda
# Processing Record 11 of Set 5 | beira
# Processing Record 12 of Set 5 | nome
# Processing Record 13 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 5 | esperance
# Processing Record 15 of Set 5 | san lawrenz
# Processing Record 16 of Set 5 | noumea
# Processing Record 17 of Set 5 | jumla
# Processing Record 18 of Set 5 | lata
# Processing Record 19 of Set 5 | broome
# Processing Record 20 of Set 5 | tasiilaq
# Processing Record 21 of Set 5 | koungou
# Processing Record 22 of Set 5 | tiarei
# Processing Record 23 of Set 5 | ostrovnoy
# Processing Record 24 of Set 5 | udachnyy
# Processing Record 25 of Set 5 | panama city
# Processing Record 26 of Set 5 | provideniya
# Processing Record 27 of Set 5 | khatanga
# Processing Record 28 of Set 5 | sakakah
# Processing Record 29 of Set 5 | salinopolis
# Processing Record 30 of Set 5 | karaton
# Processing Record 31 of Set 5 | abha
# Processing Record 32 of Set 5 | pisco
# Processing Record 33 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 5 | rawson
# Processing Record 35 of Set 5 | teya
# Processing Record 36 of Set 5 | el badari
# City not found. Skipping...
# Processing Record 37 of Set 5 | ahipara
# Processing Record 38 of Set 5 | show low
# Processing Record 39 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 5 | novo aripuana
# Processing Record 42 of Set 5 | itapirapua
# Processing Record 43 of Set 5 | banjar
# Processing Record 44 of Set 5 | walvis bay
# Processing Record 45 of Set 5 | kerema
# Processing Record 46 of Set 5 | kieta
# Processing Record 47 of Set 5 | makrana
# Processing Record 48 of Set 5 | aptos
# Processing Record 49 of Set 5 | inhambane
# Processing Record 50 of Set 5 | baddomalhi
# Processing Record 1 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 6 | burnie
# Processing Record 3 of Set 6 | kiama
# Processing Record 4 of Set 6 | kenai
# Processing Record 5 of Set 6 | pemagatsel
# Processing Record 6 of Set 6 | moerai
# Processing Record 7 of Set 6 | gairo
# Processing Record 8 of Set 6 | kushiro
# Processing Record 9 of Set 6 | tabou
# Processing Record 10 of Set 6 | manado
# Processing Record 11 of Set 6 | beyneu
# Processing Record 12 of Set 6 | esmeraldas
# Processing Record 13 of Set 6 | caravelas
# Processing Record 14 of Set 6 | katsuura
# Processing Record 15 of Set 6 | corinto
# Processing Record 16 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 6 | laguna
# Processing Record 18 of Set 6 | mwene-ditu
# Processing Record 19 of Set 6 | podgornoye
# Processing Record 20 of Set 6 | roebourne
# Processing Record 21 of Set 6 | chardara
# Processing Record 22 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 6 | songkhla
# Processing Record 24 of Set 6 | manta
# Processing Record 25 of Set 6 | west plains
# Processing Record 26 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 6 | norman wells
# Processing Record 28 of Set 6 | raga
# Processing Record 29 of Set 6 | okha
# Processing Record 30 of Set 6 | waipawa
# Processing Record 31 of Set 6 | clyde river
# Processing Record 32 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 33 of Set 6 | meulaboh
# Processing Record 34 of Set 6 | narsaq
# Processing Record 35 of Set 6 | dodoma
# Processing Record 36 of Set 6 | ayer itam
# City not found. Skipping...
# Processing Record 37 of Set 6 | irklievskaya
# City not found. Skipping...
# Processing Record 38 of Set 6 | gurgan
# City not found. Skipping...
# Processing Record 39 of Set 6 | altay
# Processing Record 40 of Set 6 | bagdarin
# Processing Record 41 of Set 6 | balkhash
# Processing Record 42 of Set 6 | palmer
# Processing Record 43 of Set 6 | broken hill
# Processing Record 44 of Set 6 | bure
# Processing Record 45 of Set 6 | san rafael
# Processing Record 46 of Set 6 | anadyr
# Processing Record 47 of Set 6 | rognan
# Processing Record 48 of Set 6 | suez
# Processing Record 49 of Set 6 | sao joao del rei
# Processing Record 50 of Set 6 | talnakh
# Processing Record 1 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 7 | melbu
# Processing Record 3 of Set 7 | cayenne
# Processing Record 4 of Set 7 | tazovskiy
# Processing Record 5 of Set 7 | vila
# Processing Record 6 of Set 7 | biak
# Processing Record 7 of Set 7 | outjo
# Processing Record 8 of Set 7 | beloha
# Processing Record 9 of Set 7 | samarai
# Processing Record 10 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 7 | ismailia
# Processing Record 12 of Set 7 | tungor
# Processing Record 13 of Set 7 | sur
# Processing Record 14 of Set 7 | coihaique
# Processing Record 15 of Set 7 | manggar
# Processing Record 16 of Set 7 | richards bay
# Processing Record 17 of Set 7 | shiloh
# Processing Record 18 of Set 7 | lubango
# Processing Record 19 of Set 7 | matagami
# Processing Record 20 of Set 7 | kroya
# Processing Record 21 of Set 7 | launceston
# Processing Record 22 of Set 7 | chicama
# Processing Record 23 of Set 7 | krasnoselkup
# Processing Record 24 of Set 7 | haines junction
# Processing Record 25 of Set 7 | nuuk
# Processing Record 26 of Set 7 | aksu
# Processing Record 27 of Set 7 | houma
# Processing Record 28 of Set 7 | general pico
# Processing Record 29 of Set 7 | yaan
# Processing Record 30 of Set 7 | cockburn town
# Processing Record 31 of Set 7 | vernon
# Processing Record 32 of Set 7 | norrtalje
# Processing Record 33 of Set 7 | keskin
# Processing Record 34 of Set 7 | ocos
# Processing Record 35 of Set 7 | torbay
# Processing Record 36 of Set 7 | beaumont
# Processing Record 37 of Set 7 | praia da vitoria
# Processing Record 38 of Set 7 | koscierzyna
# Processing Record 39 of Set 7 | grand-lahou
# Processing Record 40 of Set 7 | xinan
# Processing Record 41 of Set 7 | lavrentiya
# Processing Record 42 of Set 7 | ust-karsk
# Processing Record 43 of Set 7 | raudeberg
# Processing Record 44 of Set 7 | padang
# Processing Record 45 of Set 7 | tateyama
# Processing Record 46 of Set 7 | qinhuangdao
# Processing Record 47 of Set 7 | marsa matruh
# Processing Record 48 of Set 7 | acuna
# City not found. Skipping...
# Processing Record 49 of Set 7 | vostok
# Processing Record 50 of Set 7 | vanavara
# Processing Record 1 of Set 8 | kattivakkam
# Processing Record 2 of Set 8 | mbanza-ngungu
# Processing Record 3 of Set 8 | yulara
# Processing Record 4 of Set 8 | karasuk
# Processing Record 5 of Set 8 | grants pass
# Processing Record 6 of Set 8 | trincomalee
# Processing Record 7 of Set 8 | tavricheskoye
# Processing Record 8 of Set 8 | nueva loja
# Processing Record 9 of Set 8 | jomalig
# City not found. Skipping...
# Processing Record 10 of Set 8 | moron
# Processing Record 11 of Set 8 | brae
# Processing Record 12 of Set 8 | leshukonskoye
# Processing Record 13 of Set 8 | aliaga
# Processing Record 14 of Set 8 | lamar
# Processing Record 15 of Set 8 | semey
# Processing Record 16 of Set 8 | kangaatsiaq
# Processing Record 17 of Set 8 | saint-louis
# Processing Record 18 of Set 8 | manhuacu
# Processing Record 19 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 8 | cheltenham
# Processing Record 21 of Set 8 | bembereke
# Processing Record 22 of Set 8 | klaksvik
# Processing Record 23 of Set 8 | abu dhabi
# Processing Record 24 of Set 8 | najran
# Processing Record 25 of Set 8 | sulangan
# Processing Record 26 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 8 | winnemucca
# Processing Record 28 of Set 8 | gulshat
# City not found. Skipping...
# Processing Record 29 of Set 8 | russell
# Processing Record 30 of Set 8 | aiken
# Processing Record 31 of Set 8 | port lincoln
# Processing Record 32 of Set 8 | quebec
# Processing Record 33 of Set 8 | bengkulu
# Processing Record 34 of Set 8 | tulagi
# Processing Record 35 of Set 8 | te anau
# Processing Record 36 of Set 8 | edson
# Processing Record 37 of Set 8 | shiyan
# Processing Record 38 of Set 8 | xinzhi
# Processing Record 39 of Set 8 | yusva
# City not found. Skipping...
# Processing Record 40 of Set 8 | ambilobe
# Processing Record 41 of Set 8 | banyo
# Processing Record 42 of Set 8 | sola
# Processing Record 43 of Set 8 | labytnangi
# Processing Record 44 of Set 8 | arbuzynka
# Processing Record 45 of Set 8 | jutiquile
# Processing Record 46 of Set 8 | rodrigues alves
# Processing Record 47 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 8 | mugla
# Processing Record 49 of Set 8 | qasigiannguit
# Processing Record 50 of Set 8 | melykut
# Processing Record 1 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 9 | nouadhibou
# Processing Record 3 of Set 9 | salvatierra
# Processing Record 4 of Set 9 | mount isa
# Processing Record 5 of Set 9 | pangody
# Processing Record 6 of Set 9 | coquimbo
# Processing Record 7 of Set 9 | maltahohe
# Processing Record 8 of Set 9 | hualmay
# Processing Record 9 of Set 9 | kyzyl-suu
# Processing Record 10 of Set 9 | vila velha
# Processing Record 11 of Set 9 | bonavista
# Processing Record 12 of Set 9 | luwuk
# Processing Record 13 of Set 9 | vikhorevka
# Processing Record 14 of Set 9 | khandyga
# Processing Record 15 of Set 9 | sao felix do xingu
# Processing Record 16 of Set 9 | tabligbo
# Processing Record 17 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 9 | matara
# Processing Record 19 of Set 9 | tomatlan
# Processing Record 20 of Set 9 | kango
# Processing Record 21 of Set 9 | hay river
# Processing Record 22 of Set 9 | chandbali
# Processing Record 23 of Set 9 | tura
# Processing Record 24 of Set 9 | flin flon
# Processing Record 25 of Set 9 | timmins
# Processing Record 26 of Set 9 | franklin
# Processing Record 27 of Set 9 | de aar
# Processing Record 28 of Set 9 | limbang
# Processing Record 29 of Set 9 | neverkino
# Processing Record 30 of Set 9 | sisimiut
# Processing Record 31 of Set 9 | kruisfontein
# Processing Record 32 of Set 9 | san patricio
# Processing Record 33 of Set 9 | vestmanna
# Processing Record 34 of Set 9 | ouesso
# Processing Record 35 of Set 9 | mayumba
# Processing Record 36 of Set 9 | kaseda
# Processing Record 37 of Set 9 | mitsamiouli
# Processing Record 38 of Set 9 | mecca
# Processing Record 39 of Set 9 | benguela
# Processing Record 40 of Set 9 | mehamn
# Processing Record 41 of Set 9 | port blair
# Processing Record 42 of Set 9 | shingu
# Processing Record 43 of Set 9 | phalaborwa
# Processing Record 44 of Set 9 | lorengau
# Processing Record 45 of Set 9 | los llanos de aridane
# Processing Record 46 of Set 9 | lakes entrance
# Processing Record 47 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 9 | mantua
# Processing Record 49 of Set 9 | gimli
# Processing Record 50 of Set 9 | kodinsk
# Processing Record 1 of Set 10 | rockhampton
# Processing Record 2 of Set 10 | jinsha
# Processing Record 3 of Set 10 | mananjary
# Processing Record 4 of Set 10 | sungurlu
# Processing Record 5 of Set 10 | flinders
# Processing Record 6 of Set 10 | agadez
# Processing Record 7 of Set 10 | el wasta
# City not found. Skipping...
# Processing Record 8 of Set 10 | chapleau
# Processing Record 9 of Set 10 | opuwo
# Processing Record 10 of Set 10 | tautira
# Processing Record 11 of Set 10 | awbari
# Processing Record 12 of Set 10 | bemidji
# Processing Record 13 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 10 | goderich
# Processing Record 15 of Set 10 | usoke
# Processing Record 16 of Set 10 | hisai
# Processing Record 17 of Set 10 | fairbanks
# Processing Record 18 of Set 10 | namibe
# Processing Record 19 of Set 10 | ancud
# Processing Record 20 of Set 10 | umm kaddadah
# Processing Record 21 of Set 10 | rock sound
# Processing Record 22 of Set 10 | tupik
# Processing Record 23 of Set 10 | katsuyama
# Processing Record 24 of Set 10 | deputatskiy
# Processing Record 25 of Set 10 | baturaja
# Processing Record 26 of Set 10 | pangnirtung
# Processing Record 27 of Set 10 | strezhevoy
# Processing Record 28 of Set 10 | namatanai
# Processing Record 29 of Set 10 | sultanpur
# Processing Record 30 of Set 10 | pekan
# Processing Record 31 of Set 10 | khrebtovaya
# Processing Record 32 of Set 10 | tobermory
# Processing Record 33 of Set 10 | west wendover
# Processing Record 34 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 10 | destin
# Processing Record 36 of Set 10 | san cristobal
# Processing Record 37 of Set 10 | berlevag
# Processing Record 38 of Set 10 | paamiut
# Processing Record 39 of Set 10 | san juan
# Processing Record 40 of Set 10 | vera cruz
# Processing Record 41 of Set 10 | along
# Processing Record 42 of Set 10 | choya
# Processing Record 43 of Set 10 | plettenberg bay
# Processing Record 44 of Set 10 | hlobyne
# Processing Record 45 of Set 10 | adre
# Processing Record 46 of Set 10 | isangel
# Processing Record 47 of Set 10 | jatibonico
# Processing Record 48 of Set 10 | dhidhdhoo
# Processing Record 49 of Set 10 | karratha
# Processing Record 50 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 11 | manali
# Processing Record 2 of Set 11 | geraldton
# Processing Record 3 of Set 11 | virden
# Processing Record 4 of Set 11 | keningau
# Processing Record 5 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 11 | trelew
# Processing Record 7 of Set 11 | malanville
# Processing Record 8 of Set 11 | toba
# Processing Record 9 of Set 11 | taozhuang
# Processing Record 10 of Set 11 | nacogdoches
# Processing Record 11 of Set 11 | kirkland lake
# Processing Record 12 of Set 11 | tahta
# Processing Record 13 of Set 11 | fort madison
# Processing Record 14 of Set 11 | visnes
# Processing Record 15 of Set 11 | tucuman
# Processing Record 16 of Set 11 | three hills
# Processing Record 17 of Set 11 | borama
# City not found. Skipping...
# Processing Record 18 of Set 11 | seymchan
# Processing Record 19 of Set 11 | encruzilhada do sul
# Processing Record 20 of Set 11 | totness
# Processing Record 21 of Set 11 | pacific grove
# Processing Record 22 of Set 11 | kolyshley
# Processing Record 23 of Set 11 | egvekinot
# Processing Record 24 of Set 11 | dali
# Processing Record 25 of Set 11 | kure
# Processing Record 26 of Set 11 | skibotn
# Processing Record 27 of Set 11 | cabo san lucas
# Processing Record 28 of Set 11 | marystown
# Processing Record 29 of Set 11 | collie
# Processing Record 30 of Set 11 | avare
# Processing Record 31 of Set 11 | inta
# Processing Record 32 of Set 11 | tual
# Processing Record 33 of Set 11 | soldatskiy
# City not found. Skipping...
# Processing Record 34 of Set 11 | mandalgovi
# Processing Record 35 of Set 11 | swan hill
# Processing Record 36 of Set 11 | buritis
# Processing Record 37 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 11 | muhos
# Processing Record 39 of Set 11 | hearst
# Processing Record 40 of Set 11 | honningsvag
# Processing Record 41 of Set 11 | mahon
# Processing Record 42 of Set 11 | aracinovo
# City not found. Skipping...
# Processing Record 43 of Set 11 | baghdad
# Processing Record 44 of Set 11 | leningradskiy
# Processing Record 45 of Set 11 | banfora
# Processing Record 46 of Set 11 | lodja
# Processing Record 47 of Set 11 | sinnamary
# Processing Record 48 of Set 11 | madimba
# Processing Record 49 of Set 11 | bacolod
# Processing Record 50 of Set 11 | necochea
# Processing Record 1 of Set 12 | brenham
# Processing Record 2 of Set 12 | khandagayty
# Processing Record 3 of Set 12 | alenquer
# Processing Record 4 of Set 12 | viedma
# Processing Record 5 of Set 12 | araguaina
# Processing Record 6 of Set 12 | ada
# Processing Record 7 of Set 12 | jonkoping
# Processing Record 8 of Set 12 | sioux lookout
# Processing Record 9 of Set 12 | scarborough
# Processing Record 10 of Set 12 | fortuna foothills
# Processing Record 11 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 12 | wagar
# Processing Record 13 of Set 12 | kavaratti
# Processing Record 14 of Set 12 | port hedland
# Processing Record 15 of Set 12 | fonte boa
# Processing Record 16 of Set 12 | rio gallegos
# Processing Record 17 of Set 12 | puksoozero
# Processing Record 18 of Set 12 | navirai
# Processing Record 19 of Set 12 | safaga
# Processing Record 20 of Set 12 | kirakira
# Processing Record 21 of Set 12 | mathathane
# Processing Record 22 of Set 12 | pavino
# Processing Record 23 of Set 12 | shelburne
# Processing Record 24 of Set 12 | dumas
# Processing Record 25 of Set 12 | tonantins
# Processing Record 26 of Set 12 | kommunar
# Processing Record 27 of Set 12 | pemba
# Processing Record 28 of Set 12 | bara
# Processing Record 29 of Set 12 | vardo
# Processing Record 30 of Set 12 | port hardy
# Processing Record 31 of Set 12 | grindavik
# Processing Record 32 of Set 12 | mopti
# Processing Record 33 of Set 12 | mankono
# Processing Record 34 of Set 12 | zhangye
# Processing Record 35 of Set 12 | rosa zarate
# Processing Record 36 of Set 12 | manono
# Processing Record 37 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 38 of Set 12 | sampit
# Processing Record 39 of Set 12 | cap malheureux
# Processing Record 40 of Set 12 | fort frances
# Processing Record 41 of Set 12 | watsa
# Processing Record 42 of Set 12 | partestii de jos
# Processing Record 43 of Set 12 | saint-augustin
# Processing Record 44 of Set 12 | sabha
# Processing Record 45 of Set 12 | bougouni
# Processing Record 46 of Set 12 | hurghada
# Processing Record 47 of Set 12 | mpika
# Processing Record 48 of Set 12 | acapulco
# Processing Record 49 of Set 12 | warrensburg
# Processing Record 50 of Set 12 | bantva
# Processing Record 1 of Set 13 | imbituba
# Processing Record 2 of Set 13 | hokitika
# Processing Record 3 of Set 13 | prado
# Processing Record 4 of Set 13 | macon
# Processing Record 5 of Set 13 | dongli
# Processing Record 6 of Set 13 | bogovarovo
# Processing Record 7 of Set 13 | cartagena
# Processing Record 8 of Set 13 | pokaran
# Processing Record 9 of Set 13 | zinder
# Processing Record 10 of Set 13 | ampanihy
# Processing Record 11 of Set 13 | bacalar
# Processing Record 12 of Set 13 | mahebourg
# Processing Record 13 of Set 13 | ust-barguzin
# Processing Record 14 of Set 13 | chapais
# Processing Record 15 of Set 13 | avera
# Processing Record 16 of Set 13 | dergachi
# Processing Record 17 of Set 13 | slonim
# Processing Record 18 of Set 13 | chivilcoy
# Processing Record 19 of Set 13 | kyzyl
# Processing Record 20 of Set 13 | beringovskiy
# Processing Record 21 of Set 13 | misratah
# Processing Record 22 of Set 13 | yar-sale
# Processing Record 23 of Set 13 | edd
# Processing Record 24 of Set 13 | burica
# City not found. Skipping...
# Processing Record 25 of Set 13 | jinchang
# Processing Record 26 of Set 13 | antsla
# Processing Record 27 of Set 13 | grand island
# Processing Record 28 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 13 | santa cruz cabralia
# Processing Record 30 of Set 13 | buala
# Processing Record 31 of Set 13 | lodwar
# Processing Record 32 of Set 13 | linares
# Processing Record 33 of Set 13 | nanortalik
# Processing Record 34 of Set 13 | xingcheng
# Processing Record 35 of Set 13 | kurchum
# Processing Record 36 of Set 13 | mao
# Processing Record 37 of Set 13 | komsomolskiy
# Processing Record 38 of Set 13 | wajima
# Processing Record 39 of Set 13 | hwange
# Processing Record 40 of Set 13 | chokurdakh
# Processing Record 41 of Set 13 | humberto de campos
# Processing Record 42 of Set 13 | menzelinsk
# Processing Record 43 of Set 13 | ust-nera
# Processing Record 44 of Set 13 | barcelos
# Processing Record 45 of Set 13 | lucapa
# Processing Record 46 of Set 13 | yumen
# Processing Record 47 of Set 13 | muros
# Processing Record 48 of Set 13 | alyangula
# Processing Record 49 of Set 13 | andrews
# Processing Record 50 of Set 13 | kununurra
# Processing Record 1 of Set 14 | nicolas bravo
# Processing Record 2 of Set 14 | santa rosalia
# Processing Record 3 of Set 14 | cody
# Processing Record 4 of Set 14 | yekepa
# Processing Record 5 of Set 14 | almaznyy
# Processing Record 6 of Set 14 | banda aceh
# Processing Record 7 of Set 14 | hargeysa
# Processing Record 8 of Set 14 | tiznit
# Processing Record 9 of Set 14 | haapiti
# Processing Record 10 of Set 14 | dengzhou
# Processing Record 11 of Set 14 | pinega
# Processing Record 12 of Set 14 | sivas
# Processing Record 13 of Set 14 | kendari
# Processing Record 14 of Set 14 | bilasipara
# Processing Record 15 of Set 14 | dicabisagan
# Processing Record 16 of Set 14 | kuhdasht
# Processing Record 17 of Set 14 | warmbad
# Processing Record 18 of Set 14 | vagay
# Processing Record 19 of Set 14 | mahanoro
# Processing Record 20 of Set 14 | le vauclin
# Processing Record 21 of Set 14 | price
# Processing Record 22 of Set 14 | kaeo
# Processing Record 23 of Set 14 | matameye
# City not found. Skipping...
# Processing Record 24 of Set 14 | altamira
# Processing Record 25 of Set 14 | bull savanna
# Processing Record 26 of Set 14 | segou
# Processing Record 27 of Set 14 | sao jose da coroa grande
# Processing Record 28 of Set 14 | hollister
# Processing Record 29 of Set 14 | robertsport
# Processing Record 30 of Set 14 | pio xii
# Processing Record 31 of Set 14 | ganta
# Processing Record 32 of Set 14 | guerrero
# Processing Record 33 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 34 of Set 14 | lasa
# Processing Record 35 of Set 14 | camocim
# Processing Record 36 of Set 14 | chistogorskiy
# Processing Record 37 of Set 14 | sfantu gheorghe
# Processing Record 38 of Set 14 | longhua
# Processing Record 39 of Set 14 | maua
# Processing Record 40 of Set 14 | pandan
# Processing Record 41 of Set 14 | ilebo
# Processing Record 42 of Set 14 | ilo
# Processing Record 43 of Set 14 | san benito
# Processing Record 44 of Set 14 | durango
# Processing Record 45 of Set 14 | sorland
# Processing Record 46 of Set 14 | belyy yar
# Processing Record 47 of Set 14 | havoysund
# Processing Record 48 of Set 14 | vallenar
# Processing Record 49 of Set 14 | pevek
# Processing Record 50 of Set 14 | roma
# Processing Record 1 of Set 15 | esmeralda
# Processing Record 2 of Set 15 | hirara
# Processing Record 3 of Set 15 | luxeuil-les-bains
# Processing Record 4 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 15 | wolmaranstad
# City not found. Skipping...
# Processing Record 6 of Set 15 | novobirilyussy
# Processing Record 7 of Set 15 | sambava
# Processing Record 8 of Set 15 | say
# Processing Record 9 of Set 15 | asau
# Processing Record 10 of Set 15 | boddam
# Processing Record 11 of Set 15 | puerto colombia
# Processing Record 12 of Set 15 | malindi
# Processing Record 13 of Set 15 | xuddur
# Processing Record 14 of Set 15 | puerto cabezas
# Processing Record 15 of Set 15 | hami
# Processing Record 16 of Set 15 | chaman
# Processing Record 17 of Set 15 | aquiraz
# Processing Record 18 of Set 15 | santa maria
# Processing Record 19 of Set 15 | jalu
# Processing Record 20 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 15 | cusuna
# Processing Record 22 of Set 15 | quatre cocos
# Processing Record 23 of Set 15 | bam
# Processing Record 24 of Set 15 | waikuku
# Processing Record 25 of Set 15 | riyadh
# Processing Record 26 of Set 15 | dryden
# Processing Record 27 of Set 15 | bandarbeyla
# Processing Record 28 of Set 15 | naze
# Processing Record 29 of Set 15 | monticello
# Processing Record 30 of Set 15 | ratnagiri
# Processing Record 31 of Set 15 | skjervoy
# Processing Record 32 of Set 15 | chatra
# Processing Record 33 of Set 15 | saint-joseph
# Processing Record 34 of Set 15 | poum
# Processing Record 35 of Set 15 | nova olinda do norte
# Processing Record 36 of Set 15 | bilibino
# Processing Record 37 of Set 15 | porto novo
# Processing Record 38 of Set 15 | takoradi
# Processing Record 39 of Set 15 | manokwari
# Processing Record 40 of Set 15 | skovorodino
# Processing Record 41 of Set 15 | tanabe
# Processing Record 42 of Set 15 | balabac
# Processing Record 43 of Set 15 | boshnyakovo
# Processing Record 44 of Set 15 | botngard
# Processing Record 45 of Set 15 | alexandria
# Processing Record 46 of Set 15 | harper
# Processing Record 47 of Set 15 | pitimbu
# Processing Record 48 of Set 15 | sept-iles
# Processing Record 49 of Set 15 | portland
# Processing Record 50 of Set 15 | belaya gora
# Processing Record 1 of Set 16 | erzin
# Processing Record 2 of Set 16 | antofagasta
# Processing Record 3 of Set 16 | yuancheng
# Processing Record 4 of Set 16 | wasilla
# Processing Record 5 of Set 16 | palamos
# Processing Record 6 of Set 16 | mayo
# Processing Record 7 of Set 16 | mastic beach
# Processing Record 8 of Set 16 | sacramento
# Processing Record 9 of Set 16 | deloraine
# Processing Record 10 of Set 16 | gravelbourg
# Processing Record 11 of Set 16 | dibombari
# Processing Record 12 of Set 16 | salalah
# Processing Record 13 of Set 16 | tuymazy
# Processing Record 14 of Set 16 | tongliao
# Processing Record 15 of Set 16 | miri
# Processing Record 16 of Set 16 | alekseyevsk
# Processing Record 17 of Set 16 | nizhniy ingash
# Processing Record 18 of Set 16 | wattegama
# Processing Record 19 of Set 16 | mersing
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather']
city_data_df = city_data_df[new_column_order]
city_data_df.tail()
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 707            Miri      MY  2021-09-29 03:08:19   4.4148  114.0089     86.02
# 708     Alekseyevsk      RU  2021-09-29 03:08:20  57.8406  108.3492     37.27
# 709  Nizhniy Ingash      RU  2021-09-29 03:08:20  56.2000   96.5300     36.00
# 710       Wattegama      LK  2021-09-29 03:08:21   6.7989   81.4808     81.52
# 711         Mersing      MY  2021-09-29 03:08:21   2.4312  103.8405     86.27
#
#      Humidity  Cloudiness  Wind Speed          Weather
# 707        67          76        4.90    broken clouds
# 708        86          99        5.95  overcast clouds
# 709        88         100        1.79  overcast clouds
# 710        50          87        1.59  overcast clouds
# 711        66         100        1.10  overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

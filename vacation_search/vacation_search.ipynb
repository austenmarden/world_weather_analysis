# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df
# Out:
#      City_ID            City Country                 Date      Lat       Lng  \
# 0          0          Waddan      LY  2021-09-29 03:04:51  29.1614   16.1390
# 1          1         Mataura      NZ  2021-09-29 03:04:52 -46.1927  168.8643
# 2          2        Souillac      MU  2021-09-29 02:55:42 -20.5167   57.5167
# 3          3          Hasaki      JP  2021-09-29 02:56:07  35.7333  140.8333
# 4          4          Albany      US  2021-09-29 03:04:16  42.6001  -73.9662
# ..       ...             ...     ...                  ...      ...       ...
# 707      707            Miri      MY  2021-09-29 03:08:19   4.4148  114.0089
# 708      708     Alekseyevsk      RU  2021-09-29 03:08:20  57.8406  108.3492
# 709      709  Nizhniy Ingash      RU  2021-09-29 03:08:20  56.2000   96.5300
# 710      710       Wattegama      LK  2021-09-29 03:08:21   6.7989   81.4808
# 711      711         Mersing      MY  2021-09-29 03:08:21   2.4312  103.8405
#
#      Max Temp  Humidity  Cloudiness  Wind Speed          Weather
# 0       73.94        32           0        3.89        clear sky
# 1       47.48        92          88        7.70  overcast clouds
# 2       74.35        68          75       11.50    broken clouds
# 3       77.29        65          89       11.12  overcast clouds
# 4       55.58        73          99        5.01  overcast clouds
# ..        ...       ...         ...         ...              ...
# 707     86.02        67          76        4.90    broken clouds
# 708     37.27        86          99        5.95  overcast clouds
# 709     36.00        88         100        1.79  overcast clouds
# 710     81.52        50          87        1.59  overcast clouds
# 711     86.27        66         100        1.10  overcast clouds
#
# [712 rows x 11 columns]

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("Please enter your minimum temperature preference."))
max_temp = float(input("Please enter your maximum temperature preference."))

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
pref_cities = city_data_df.loc[(city_data_df['Max Temp'] >= min_temp) & (city_data_df['Max Temp'] <= max_temp)]

# %%
# 4a. Determine if there are any empty rows.
pref_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 3 to 711
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City_ID     219 non-null    int64
#  1   City        219 non-null    object
#  2   Country     219 non-null    object
#  3   Date        219 non-null    object
#  4   Lat         219 non-null    float64
#  5   Lng         219 non-null    float64
#  6   Max Temp    219 non-null    float64
#  7   Humidity    219 non-null    int64
#  8   Cloudiness  219 non-null    int64
#  9   Wind Speed  219 non-null    float64
#  10  Weather     219 non-null    object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 20.5+ KB

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
pref_cities
# Out:
#      City_ID             City Country                 Date      Lat       Lng  \
# 3          3           Hasaki      JP  2021-09-29 02:56:07  35.7333  140.8333
# 6          6       Butaritari      KI  2021-09-29 03:04:53   3.0707  172.7902
# 10        10      Kloulklubed      PW  2021-09-29 03:04:53   7.0419  134.2556
# 12        12  Bandar-E Lengeh      IR  2021-09-29 03:04:54  26.5579   54.8807
# 20        20            Kapaa      US  2021-09-29 03:04:19  22.0752 -159.3190
# ..       ...              ...     ...                  ...      ...       ...
# 689      689          Pitimbu      BR  2021-09-29 03:08:15  -7.4706  -34.8086
# 704      704          Salalah      OM  2021-09-29 03:04:28  17.0151   54.0924
# 707      707             Miri      MY  2021-09-29 03:08:19   4.4148  114.0089
# 710      710        Wattegama      LK  2021-09-29 03:08:21   6.7989   81.4808
# 711      711          Mersing      MY  2021-09-29 03:08:21   2.4312  103.8405
#
#      Max Temp  Humidity  Cloudiness  Wind Speed           Weather
# 3       77.29        65          89       11.12   overcast clouds
# 6       83.55        73          66       19.33     broken clouds
# 10      88.30        71         100        9.28   overcast clouds
# 12      87.21        61          32        3.74  scattered clouds
# 20      84.18        79          75        4.00        light rain
# ..        ...       ...         ...         ...               ...
# 689     75.33        84          55       11.43     broken clouds
# 704     78.89        78           0        2.30         clear sky
# 707     86.02        67          76        4.90     broken clouds
# 710     81.52        50          87        1.59   overcast clouds
# 711     86.27        66         100        1.10   overcast clouds
#
# [219 rows x 11 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = pref_cities[["City", "Country", "Max Temp", "Weather", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp           Weather      Lat       Lng  \
# 3            Hasaki      JP     77.29   overcast clouds  35.7333  140.8333
# 6        Butaritari      KI     83.55     broken clouds   3.0707  172.7902
# 10      Kloulklubed      PW     88.30   overcast clouds   7.0419  134.2556
# 12  Bandar-E Lengeh      IR     87.21  scattered clouds  26.5579   54.8807
# 20            Kapaa      US     84.18        light rain  22.0752 -159.3190
# 21            Arlit      NE     86.54  scattered clouds  18.7369    7.3853
# 29        Gushikawa      JP     88.83     broken clouds  26.3544  127.8686
# 30           Atuona      PF     78.03         clear sky  -9.8000 -139.0333
# 34            Vaini      TO     78.96        few clouds -21.2000 -175.2000
# 45            Airai      TL     82.31        few clouds  -8.9266  125.4092
#
#    Hotel Name
# 3
# 6
# 10
# 12
# 20
# 21
# 29
# 30
# 34
# 45

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key,
    "location": ""
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row['Lat']
    lng = row['Lng']
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
        
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        
        print('Hotel for ' + hotel_df.loc[index, 'City'] + ' is: ' + hotel_df.loc[index, "Hotel Name"])
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel for Hasaki is: Hotel Sunrise Choshi
# Hotel for Butaritari is: Isles Sunset Lodge
# Hotel for Kloulklubed is: Storyboard Beach Resort
# Hotel for Bandar-E Lengeh is: کافی نت پارس
# Hotel for Kapaa is: Sheraton Kauai Coconut Beach Resort
# Hotel for Arlit is: Case de Passage De la Prefecture
# Hotel for Gushikawa is: Kirari Guest House
# Hotel for Atuona is: Villa Enata
# Hotel for Vaini is: Keleti Beach Resort
# Hotel for Airai is: Juvinal Martin
# Hotel for Praya is: LT Aparthotel
# Hotel for Cururupu is: POUSADA TRAVÉS'CIA
# Hotel for Kavieng is: Nusa Island Retreat
# Hotel for Puerto Quijarro is: Hotel palance
# Hotel for Liku is: Wahyu
# Hotel for Trairi is: janelas do mar
# Hotel not found... skipping.
# Hotel for Dingle is: SEGAYA PROPERTY
# Hotel for Pailon is: Alojamiento pailon
# Hotel for Gizo is: Imagination Island
# Hotel for Mount Pleasant is: Best Western Patriots Point
# Hotel for Santa Rosa is: Erlyn’s Sta Rosa City Home
# Hotel for Islamkot is: Haji Hotel
# Hotel for Kahului is: Maui Seaside Hotel
# Hotel for Faanui is: Bora-Bora Pearl Beach Resort & Spa
# Hotel for Saint George is: Best Western Plus Abbey Inn
# Hotel for Akyab is: Hotel Memory
# Hotel for Rabaul is: Rabaul Hotel
# Hotel for Carutapera is: Lidera
# Hotel for Hithadhoo is: Scoop Guest House
# Hotel for Kodinar is: residency of N.B vadhel
# Hotel for Axim is: Axim Beach Resort And Spa
# Hotel for Puerto Escondido is: Aldea del Bazar Hotel and Spa
# Hotel for Sakaiminato is: 味処・民宿 まつや
# Hotel for Itarema is: Sea Lounge! Bar, Club & Restaurant
# Hotel not found... skipping.
# Hotel for Sabang is: Hotel Citra
# Hotel for Pontes E Lacerda is: Hotel Bressan
# Hotel for Neiafu is: Mystic Sands Beachfront Accommodation
# Hotel for Alofi is: Taloa Heights
# Hotel for Lantana is: Four Seasons Resort Palm Beach
# Hotel for Santa Cruz is: Aviador Hotel Boutique
# Hotel for Port Macquarie is: Rydges Port Macquarie
# Hotel for Paracuru is: Hotel Vento Brasil
# Hotel for Avarua is: Paradise Inn
# Hotel for Mahibadhoo is: Omadhoo Inn
# Hotel for El Reno is: Home2 Suites by Hilton El Reno
# Hotel for Sao Filipe is: Hotel Xaguate
# Hotel for Georgetown is: Cititel Penang
# Hotel not found... skipping.
# Hotel for Bathsheba is: Atlantis Hotel
# Hotel for Carnarvon is: Hospitality Carnarvon
# Hotel for Hilo is: Hilo Hawaiian Hotel
# Hotel for The Valley is: CeBlue Villas & Beach Resort
# Hotel not found... skipping.
# Hotel for Praia is: LT Aparthotel
# Hotel for San Lawrenz is: San Andrea Hotel
# Hotel for Noumea is: Hôtel Le Lagon
# Hotel for Tiarei is: Le Rocher de Tahiti
# Hotel for Panama City is: Riande Urban Hotel
# Hotel for Salinopolis is: Salinas Park Resort Maçarico AP101
# Hotel for Karaton is: Parkir Mobil Wisata CAS Water Park
# Hotel for Itapirapua is: Hotel Nossa Senhora Aparecida
# Hotel for Banjar is: The Hamsa Resort
# Hotel for Kerema is: Frena Lodge
# Hotel for Kieta is: Uruna Bay Retreat
# Hotel for Makrana is: Ganpati Guest House
# Hotel for Baddomalhi is: C,H ShAni Malhi
# Hotel for Moerai is: Le Manotel
# Hotel for Tabou is: hotêl doufoulougou
# Hotel for Katsuura is: Katsuura Hotel Mikazuki
# Hotel for Roebourne is: Latitude20 Roebourne Village
# Hotel for Songkhla is: น.ส ซัลมา สาแม็ง
# Hotel for Meulaboh is: Kost Pria
# Hotel for Broken Hill is: Royal Exchange Hotel
# Hotel for Cayenne is: Hôtel Le Dronmi
# Hotel for Biak is: Penginapan Kim
# Hotel for Samarai is: Nuli Sapi
# Hotel for Sur is: Sur Plaza Hotel
# Hotel for Manggar is: Guest Hotel
# Hotel for Shiloh is: Hilton Garden Inn St. Louis Shiloh/O’Fallon IL
# Hotel for Cockburn Town is: Osprey Beach Hotel
# Hotel for Ocos is: Auto Hotel El Soñador
# Hotel for Xinan is: 昌雄大酒店
# Hotel for Padang is: Mercure Padang
# Hotel for Tateyama is: Tateyama Seaside Hotel
# Hotel for Kattivakkam is: Euronova Freezer
# Hotel for Trincomalee is: Welcombe Hotel
# Hotel for Aliaga is: Jhenie rich ramos
# Hotel for Lamar is: Kings Inn Paris TX
# Hotel not found... skipping.
# Hotel for Abu Dhabi is: Ramee Garden Hotel Apartments
# Hotel for Sulangan is: Maia's Beach Resort
# Hotel for Bengkulu is: Grage Hotel Bengkulu
# Hotel for Tulagi is: Raiders Hotel & Dive
# Hotel for Shiyan is: Fenghuang Garden Holiday Hotel
# Hotel for Sola is: Leumerus Bungalows
# Hotel not found... skipping.
# Hotel for Nouadhibou is: El Medina
# Hotel for Luwuk is: Hotel Santika Luwuk
# Hotel for Matara is: Amaloh Boutique Resort
# Hotel for Tomatlan is: El Salvial
# Hotel for Chandbali is: KABITA HOMES
# Hotel for Tura is: Hotel RIKMAN Continental
# Hotel for Limbang is: Purnama Hotel
# Hotel for San Patricio is: Motel 6 Sinton, TX
# Hotel for Mayumba is: LIKWALE LODGE
# Hotel for Kaseda is: Sun Stay Kaseda
# Hotel for Mitsamiouli is: Foyer ADM
# Hotel for Mecca is: Makkah Clock Royal Tower, A Fairmont Hotel
# Hotel for Port Blair is: Welcomhotel By ITC Hotels, Bay Island, Port Blair
# Hotel for Shingu is: Shingu UI Hotel
# Hotel for Lorengau is: Lorengau Harbourside Hotel
# Hotel for Rockhampton is: Mercure Rockhampton
# Hotel for Jinsha is: Cosmic Guangdong International Hotel
# Hotel not found... skipping.
# Hotel for Tautira is: Pension Oaoa
# Hotel not found... skipping.
# Hotel for Hisai is: ステーションホテルＡＵ
# Hotel not found... skipping.
# Hotel for Rock Sound is: Rock Sound Club
# Hotel for Katsuyama is: Pension UPO
# Hotel for Baturaja is: HOTEL Sekar Sunja, Baturaja Timur, Ogan Komering Ulu
# Hotel for Namatanai is: Seagulls Inn Namatani
# Hotel for Sultanpur is: OYO 49568 Vrindavan Guest House
# Hotel for Pekan is: Pekan Budget Hotel
# Hotel for Destin is: Inn On Destin Harbor-Ascend Hotel Collection
# Hotel for Along is: Hotel West
# Hotel not found... skipping.
# Hotel for Isangel is: Tanna Lodge
# Hotel for Dhidhdhoo is: Dhidhoo beach
# Hotel for Karratha is: ibis Styles Karratha
# Hotel for Manali is: Sarathy Lodge
# Hotel for Geraldton is: Broadwater Mariner Resort
# Hotel for Keningau is: Sabindo Hotel
# Hotel for Malanville is: DEVO HOTEL
# Hotel for Toba is: ホテル アルティア鳥羽
# Hotel for Taozhuang is: New Century Fengming Resort Zaozhuang
# Hotel for Nacogdoches is: The Fredonia Hotel & Convention Center
# Hotel for Totness is: STAATS LOGEERGEBOUW TOTNESS
# Hotel for Kure is: Kure Station Hotel
# Hotel for Cabo San Lucas is: Hotel Tesoro Los Cabos
# Hotel for Tual is: Grand Vilia Hotel
# Hotel for Buritis is: Hotel Rainha do Vale
# Hotel for Sinnamary is: ALETHEIA Appartement Sinnamary
# Hotel for Bacolod is: Planta Hotel & Residences
# Hotel for Brenham is: Hampton Inn & Suites Brenham
# Hotel for Alenquer is: Josilene Castro
# Hotel for Araguaina is: Hotel São Vicente
# Hotel for Fortuna Foothills is: Fortuna De Oro RV Park
# Hotel not found... skipping.
# Hotel for Kavaratti is: Hotels in Lakshadweep Islands
# Hotel for Port Hedland is: The Esplanade Hotel
# Hotel for Navirai is: Dubai Hotel - Também sua casa!
# Hotel for Safaga is: Lamar Resort Abu Soma
# Hotel for Kirakira is: SanBiz Lodge
# Hotel for Dumas is: Holiday Inn Express & Suites Dumas, an IHG Hotel
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel for Sampit is: Aquarius Boutique Hotel Sampit
# Hotel for Hurghada is: Sea Star Beau Rivage Hotel
# Hotel for Acapulco is: HS Hotsson Smart Acapulco
# Hotel for Warrensburg is: Comfort Inn Warrensburg Station
# Hotel for Bantva is: Rana Bai daga Bai
# Hotel for Dongli is: Chenghai Shizhang Donghuaqiao Hostel
# Hotel for Cartagena is: Hotel Colombia Real - Cartagena
# Hotel for Pokaran is: Motel Pokaran - RTDC
# Hotel for Zinder is: Hotel de Ville
# Hotel for Bacalar is: Hotel Laguna Bacalar
# Hotel for Misratah is: فندق الماسة
# Hotel not found... skipping.
# Hotel for Grand Island is: Fairfield Inn & Suites by Marriott Grand Island
# Hotel for Buala is: Maringe Lagoon Lodge
# Hotel for Lodwar is: Solmar Gracious Hotel
# Hotel for Wajima is: Wajiima Onsen Yashio
# Hotel for Humberto De Campos is: Pousada do Cabeça
# Hotel for Alyangula is: Groote Eylandt Lodge
# Hotel for Andrews is: Days Inn by Wyndham Andrews Texas
# Hotel for Santa Rosalia is: Hotel Las Casitas Santa Rosalia
# Hotel for Banda Aceh is: Sulthan Hotel International
# Hotel for Haapiti is: Linareva Moorea Beach Resort
# Hotel for Kendari is: Hotel Wixel
# Hotel for Bilasipara is: Inspection Bunglow
# Hotel for Dicabisagan is: Nancy Montanes Bernardo
# Hotel for Le Vauclin is: Hôtel Cap Macabou
# Hotel for Bull Savanna is: Big Red's
# Hotel for Segou is: Comme chez soi
# Hotel for Robertsport is: Kwepunha Retreat
# Hotel for Pio Xii is: BACURI DOS QUARESMAS
# Hotel for Camocim is: Hotel Ilha do Amor
# Hotel for Maua is: Hotel Capriccio Mauá
# Hotel for Pandan is: Bonifacio Lodge
# Hotel for Esmeralda is: Centro de Pioneros Exploradores
# Hotel for Hirara is: Hotel Atoll Emerald Miyakojima
# Hotel not found... skipping.
# Hotel for Puerto Colombia is: Hotel El Emigrante
# Hotel for Malindi is: African House Resort
# Hotel for Puerto Cabezas is: Cabaña Caribe
# Hotel for Chaman is: Niamat parda Center chaman
# Hotel for Aquiraz is: Pousada Rua Camurupim
# Hotel not found... skipping.
# Hotel for Bam is: Bam Tourist Hotel
# Hotel for Bandarbeyla is: JABIR HOTEL
# Hotel for Naze is: オーベルジュ・アガルイ
# Hotel for Ratnagiri is: Hotel Landmark
# Hotel for Chatra is: GOPI BHOJNALAY
# Hotel for Nova Olinda Do Norte is: Jardim Paiva Hotel
# Hotel for Porto Novo is: Tour Eiffel Hotel Benin
# Hotel for Takoradi is: Raybow International Hotel
# Hotel for Manokwari is: Swiss Belhotel Manokwari
# Hotel for Tanabe is: 美吉屋旅館
# Hotel for Balabac is: Sing and Swing Lodge
# Hotel for Alexandria is: Royal Crown Hotel
# Hotel for Harper is: Screensaver
# Hotel for Pitimbu is: Reserva do Abiaí
# Hotel for Salalah is: HAMDAN PLAZA HOTEL SALALAH
# Hotel for Miri is: Mega Hotel, Miri
# Hotel not found... skipping.
# Hotel for Mersing is: Timotel Hotel

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df['Hotel Name'].str.strip().astype(bool)]
clean_hotel_df
# Out:
#                 City Country  Max Temp           Weather      Lat       Lng  \
# 3             Hasaki      JP     77.29   overcast clouds  35.7333  140.8333
# 6         Butaritari      KI     83.55     broken clouds   3.0707  172.7902
# 10       Kloulklubed      PW     88.30   overcast clouds   7.0419  134.2556
# 12   Bandar-E Lengeh      IR     87.21  scattered clouds  26.5579   54.8807
# 20             Kapaa      US     84.18        light rain  22.0752 -159.3190
# ..               ...     ...       ...               ...      ...       ...
# 688           Harper      LR     76.59        light rain   4.3750   -7.7169
# 689          Pitimbu      BR     75.33     broken clouds  -7.4706  -34.8086
# 704          Salalah      OM     78.89         clear sky  17.0151   54.0924
# 707             Miri      MY     86.02     broken clouds   4.4148  114.0089
# 711          Mersing      MY     86.27   overcast clouds   2.4312  103.8405
#
#                               Hotel Name
# 3                   Hotel Sunrise Choshi
# 6                     Isles Sunset Lodge
# 10               Storyboard Beach Resort
# 12                          کافی نت پارس
# 20   Sheraton Kauai Coconut Beach Resort
# ..                                   ...
# 688                          Screensaver
# 689                     Reserva do Abiaí
# 704           HAMDAN PLAZA HOTEL SALALAH
# 707                     Mega Hotel, Miri
# 711                        Timotel Hotel
#
# [202 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = "weatherpy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import os
# Import the API key.
from config import g_key

# %%
cities_csv_load = os.path.join('weather_data','cities.csv')
cities_df = pd.read_csv(cities_csv_load)
cities_df.head()
# Out:
#    City_ID             City Country                 Date      Lat      Lng  \
# 0        0          Ushuaia      AR  2021-09-27 17:53:53 -54.8000 -68.3000
# 1        1      East London      ZA  2021-09-27 17:56:47 -33.0153  27.9116
# 2        2           Comrat      MD  2021-09-27 17:56:47  46.3003  28.6572
# 3        3          Homocea      RO  2021-09-27 17:56:47  46.1333  27.2333
# 4        4  Arraial Do Cabo      BR  2021-09-27 17:56:48 -22.9661 -42.0278
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     51.42        53          40        5.75
# 1     67.14        82          40       23.02
# 2     59.09        46          56        6.80
# 3     64.02        60          81        4.21
# 4     80.56        69          40       16.11

# %%
cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City_ID     562 non-null    int64
#  1   City        562 non-null    object
#  2   Country     557 non-null    object
#  3   Date        562 non-null    object
#  4   Lat         562 non-null    float64
#  5   Lng         562 non-null    float64
#  6   Max Temp    562 non-null    float64
#  7   Humidity    562 non-null    int64
#  8   Cloudiness  562 non-null    int64
#  9   Wind Speed  562 non-null    float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 44.0+ KB

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = cities_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = cities_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of Humidity
# Get the latitude and longitude.
locations = cities_df[["Lat", "Lng"]]
# Get the maximum temperature.
humidity = cities_df["Humidity"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of cloudiness
# Get the latitude and longitude.
locations = cities_df[["Lat", "Lng"]]
# Get the maximum temperature.
clouds = cities_df["Cloudiness"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of cloudiness
# Get the latitude and longitude.
locations = cities_df[["Lat", "Lng"]]
# Get the maximum temperature.
winds = cities_df["Wind Speed"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=winds, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = cities_df.loc[(cities_df["Max Temp"] <= max_temp) & \
                                       (cities_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City Country                 Date      Lat       Lng  \
# 4         4  Arraial Do Cabo      BR  2021-09-27 17:56:48 -22.9661  -42.0278
# 5         5           Albany      US  2021-09-27 17:56:48  42.6001  -73.9662
# 8         8         Sterling      US  2021-09-27 17:54:54  39.0062  -77.4286
# 10       10           Beihai      CN  2021-09-27 17:56:49  21.4833  109.1000
# 11       11             Hilo      US  2021-09-27 17:54:02  19.7297 -155.0900
# 12       12           Bethel      US  2021-09-27 17:56:50  41.3712  -73.4140
# 14       14         Dehloran      IR  2021-09-27 17:56:51  32.6941   47.2679
# 17       17        Sheboygan      US  2021-09-27 17:56:52  43.7333  -87.9334
# 22       22             Biak      ID  2021-09-27 17:56:53  -0.9131  122.8766
# 25       25         Meulaboh      ID  2021-09-27 17:56:54   4.1363   96.1285
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 4      80.56        69          40       16.11
# 5      75.74        70          83        7.20
# 8      81.77        45           1        1.99
# 10     83.62        74          22        5.32
# 11     76.80        91          90        4.61
# 12     78.03        60          75        1.01
# 14     84.92        14           0        2.62
# 17     80.82        71           9        3.00
# 22     75.33        82          92        6.02
# 25     77.09        86          97        6.78

# %%
preferred_cities_df.count()
# Out:
# City_ID       208
# City          208
# Country       206
# Date          208
# Lat           208
# Lng           208
# Max Temp      208
# Humidity      208
# Cloudiness    208
# Wind Speed    208
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp      Lat       Lng Hotel Name
# 4   Arraial Do Cabo      BR     80.56 -22.9661  -42.0278
# 5            Albany      US     75.74  42.6001  -73.9662
# 8          Sterling      US     81.77  39.0062  -77.4286
# 10           Beihai      CN     83.62  21.4833  109.1000
# 11             Hilo      US     76.80  19.7297 -155.0900
# 12           Bethel      US     78.03  41.3712  -73.4140
# 14         Dehloran      IR     84.92  32.6941   47.2679
# 17        Sheboygan      US     80.82  43.7333  -87.9334
# 22             Biak      ID     75.33  -0.9131  122.8766
# 25         Meulaboh      ID     77.09   4.1363   96.1285

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uECnRZiZbTFTn442KjF6cAlpS1FtA8EeohvdS6c1D_unRtq-AlP5ARA-Uykqw6P_3IcCvctBJi4mUF-poN3mgMr-liZtP8xTYiw6WJZLKRP4UfnRVUWU-W3qCFrNqUzOlHiQVpwSwgZaFehQcKBHy3FdKyo5LlCrC9z_DHGq5pLo6n69t6gl79kly_RtxbxmxsTPgB9k16kgE9ZCg5EkJE1MYMzVO9UrgwXCD4_zdmeWNRYPv78WklDggVm5vu_PShapZG9BSgIZ9erPfQMyxSJ_bBDDY_nlOBzB0csn1vRP-8kn7lFoH8QqETaW4aHtWVF9SJ7uxYQ7lr-q7GLZ3C4Av1EBdZTTuVxBgA2A-EHeU-FD577pKuRstxVWiDAo5md0gQOFzWZxzvmmVxL5LitD8twOAt1hndpFNiyhwKLvjgVWVUmTJEoM',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'Aap_uEB8dS7bw5R_sGsdgaUAkTekM88LQIfPUptm4cSIjTqoHWHybQSl_wQw6biOk2E6R9K1sGXWxgTspApxk9zlx9AICp9q7hKHdqrgC3Pfo221oe4AOowS9Xk9Pr9G0VWvgWOPjFBQWYb79j8byQeXY2Cp7UVt1XoyBnYDI0cujobeYy9a',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'spa',
#     'lodging',
#     'bar',
#     'gym',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 291,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.85954748029151,
#       'lng': 2.347782830291502},
#      'southwest': {'lat': 48.85684951970851, 'lng': 2.345084869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Britannique - Paris Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1426,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'],
#      'photo_reference': 'Aap_uEDd2W4MBHae3FMbGD062d_h44m5UnjCtUhQCrUCa_H4x1RriK4WxLyTeDKsqM2ZyjCeaCYW8Xk7uMc7O_y8DFYJHiCHGngstbE3RfchNEuO6gWRZ7v7cpHy965UpSu6xlPFik_DcoSpK6qUmM57QNVvD39scBT-L2OOgt71nD9fp6rm',
#      'width': 1476}],
#    'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'plus_code': {'compound_code': 'V85W+8H Paris, France',
#     'global_code': '8FW4V85W+8H'},
#    'rating': 4.6,
#    'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 607,
#    'vicinity': '20 Avenue Victoria, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293},
#     'viewport': {'northeast': {'lat': 48.8617653302915,
#       'lng': 2.348020880291502},
#      'southwest': {'lat': 48.85906736970851, 'lng': 2.345322919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Les Halles Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 849,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart hotel Paris)</a>'],
#      'photo_reference': 'Aap_uEAlpSMGfH_D_Z6Rqseog_8eT0FlcMl8jTtGwqtB5vmIdpi0uIsWj_ITJ3uJFf6ObmDm2K4aAlxj3VCG8CUIPu29An_LH6s8YEYvorgop3Qwx-B0yKkuEmUq1U2ZrWshpFx3h_fHDEDSj-iABxx-NzFDpqfsAAhjUTXpOKXwbGP78Oio',
#      'width': 1280}],
#    'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#     'global_code': '8FW4V86W+7Q'},
#    'rating': 4.1,
#    'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 856,
#    'vicinity': '4 Rue des Innocents, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607658, 'lng': 2.3465318},
#     'viewport': {'northeast': {'lat': 48.8620584302915,
#       'lng': 2.347692880291501},
#      'southwest': {'lat': 48.85936046970851, 'lng': 2.344994919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Novotel Paris Les Halles',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel Paris Les Halles</a>'],
#      'photo_reference': 'Aap_uECaPM0mBxHNbD13RpuBA_hwUFoFhBoE3CqrXH6P4bvsVeEhyrY6UMyAy1mjhggBWsHYN9nfdbkkWk8QyAkcO7nQJ6JMnan_872qrW_KzcL7YhD3TkWCo90MwAVrPpVIX7y9FeDTRGwnWNtF2-yTv2JOLqtlVOjTx9J_7g1Z7DNY7mH6',
#      'width': 3000}],
#    'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'plus_code': {'compound_code': 'V86W+8J Paris, France',
#     'global_code': '8FW4V86W+8J'},
#    'rating': 4.4,
#    'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2221,
#    'vicinity': '8 Place Marguerite de Navarre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.860352, 'lng': 2.3440948},
#     'viewport': {'northeast': {'lat': 48.86165553029149,
#       'lng': 2.345549080291502},
#      'southwest': {'lat': 48.8589575697085, 'lng': 2.342851119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Ducs de Bourgogne',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101411638353598558320">Hôtel Ducs de Bourgogne</a>'],
#      'photo_reference': 'Aap_uEA25Ua_1ccE7wny1cvZNWOu4_nnxXYhLNVEsUFF4E24MNjbsWJN-bu4iauV5l00yV8GlPyo5l9QhqqS8OQ5qCXSz8PsCXDTRAMz8aeJIfFwTybgEXv0j4D3O4ZEGoW7fzUJwPXcXQVAepQF0ubECsqlQ_zDZivJlMZhDdarYuMQ-QEf',
#      'width': 2048}],
#    'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'plus_code': {'compound_code': 'V86V+4J Paris, France',
#     'global_code': '8FW4V86V+4J'},
#    'rating': 4.5,
#    'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 279,
#    'vicinity': '19 Rue du Pont Neuf, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8555091, 'lng': 2.3408736},
#     'viewport': {'northeast': {'lat': 48.8569076302915,
#       'lng': 2.342319280291502},
#      'southwest': {'lat': 48.8542096697085, 'lng': 2.339621319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Saint-Germain-des-Prés Paris (Apart hotel Paris)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113188832595116816387">Citadines Saint-Germain-des-Prés Paris</a>'],
#      'photo_reference': 'Aap_uEAqSxmAlsdj6pzbNk6aO1xOfumVTaD2zzgfT8pi-L2TzPhG7yLsJ8YuTeQD9T9ZgzfU6YZie1NIQIzD87F95OTSoF3YxrXhD_MHMePXkA6z3_ukus6-uR3w9elEPKoCFwJYEXXVBPq8UeW15pxkOq3gbKD0DrB695MvUxgwVhd_fgom',
#      'width': 6720}],
#    'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'plus_code': {'compound_code': 'V84R+68 Paris, France',
#     'global_code': '8FW4V84R+68'},
#    'rating': 4.3,
#    'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 699,
#    'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8663519, 'lng': 2.3606461},
#     'viewport': {'northeast': {'lat': 48.86775308029149,
#       'lng': 2.361905130291502},
#      'southwest': {'lat': 48.8650551197085, 'lng': 2.359207169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Paris France Hôtel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2673,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102332962500946068613">Paris France Hôtel</a>'],
#      'photo_reference': 'Aap_uEBS9jOzP1wJ_3W49wo_-mSWo0TWuHyhdZYydVr32DhhSB6F7H1starc8K82vl_1E4nuYkHbatMlhjwmS18pihbzDFfjabZhshi0P8HtVX3PMqJJJpFHDeBb0OOV6GR2m0382q26OYwrRE-wU3mxwDpraj4XWLxs2pc-pdWIOSKHjBM5',
#      'width': 3463}],
#    'place_id': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'plus_code': {'compound_code': 'V986+G7 Paris, France',
#     'global_code': '8FW4V986+G7'},
#    'rating': 4.3,
#    'reference': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 383,
#    'vicinity': '72 Rue de Turbigo, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86386539999999, 'lng': 2.3325488},
#     'viewport': {'northeast': {'lat': 48.8650759802915,
#       'lng': 2.333775730291502},
#      'southwest': {'lat': 48.8623780197085, 'lng': 2.331077769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Regina Louvre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3700,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109908333790946649027">Hôtel Regina Louvre</a>'],
#      'photo_reference': 'Aap_uEC25CLEbrMF8Gy19BSNpJkMtWQUp1H2Zis6SpxhXAX8ORBH6_U08IqkL5B2ZDbTToGI6ZONO05i5o5Z5WST3aFgHXvLi1x5rNr0O8RElF6bvPxT-_jVtctW0tQTHE7h6JxuBmLj-lTWDLX28RVGdlpXAzDDz9gvgY74qa09A4s_TXPw',
#      'width': 5550}],
#    'place_id': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'plus_code': {'compound_code': 'V87M+G2 Paris, France',
#     'global_code': '8FW4V87M+G2'},
#    'rating': 4.5,
#    'reference': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 507,
#    'vicinity': '2 Place des Pyramides, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84795229999999, 'lng': 2.370869},
#     'viewport': {'northeast': {'lat': 48.8492035302915,
#       'lng': 2.372290080291501},
#      'southwest': {'lat': 48.8465055697085, 'lng': 2.369592119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'ibis Paris Gare de Lyon Ledru Rollin 12ème',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101181280085797863615">Kevin Nguyen</a>'],
#      'photo_reference': 'Aap_uEDQE0WTXsqzd1A5gHzNFoFJhdY28HZbLuKpKzYQ2B-AoK0Oxzt9LHDWGyL9pT-25A03bHrDj8pghcJIJQ5WvtXW8ndbaiMmXpRe-yWp7WR368xWPCJOcPNCrdoxDYQFyo7W0j3udSfWSJacOc82_kQfFXqONqYIfT9NJTPnImJsbJEz',
#      'width': 1536}],
#    'place_id': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'plus_code': {'compound_code': 'R9XC+58 Paris, France',
#     'global_code': '8FW4R9XC+58'},
#    'rating': 4,
#    'reference': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 824,
#    'vicinity': '41/43 Avenue Ledru Rollin, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8710647, 'lng': 2.34991},
#     'viewport': {'northeast': {'lat': 48.87241888029151,
#       'lng': 2.351188530291502},
#      'southwest': {'lat': 48.86972091970851, 'lng': 2.348490569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel des Comédies Paris',
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114696623290303183213">Noble</a>'],
#      'photo_reference': 'Aap_uEBYrP7SLd81bDKEUYmXW5HcaZaRJ9jyAEO_jGxzUG_f0YVkiMh8FtVN7wtkqro2sxF8o_p62VIlAtuBkvItTW4ols9ATNC7HrG1_fjQS4u7s6iyZnb-6ePwfGN8acUQW8LDmCu-XHS3cDUBIicBZdbWwjkk-nPSbwpmIwj-ink8hGJg',
#      'width': 3000}],
#    'place_id': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'plus_code': {'compound_code': 'V8CX+CX Paris, France',
#     'global_code': '8FW4V8CX+CX'},
#    'rating': 4.2,
#    'reference': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 195,
#    'vicinity': "8 Rue d'Hauteville, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84754640000001, 'lng': 2.3718722},
#     'viewport': {'northeast': {'lat': 48.8488750302915,
#       'lng': 2.373125480291502},
#      'southwest': {'lat': 48.8461770697085, 'lng': 2.370427519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel De France Gare de Lyon Bastille',
#    'photos': [{'height': 787,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117462031751048846575">Hôtel De France Gare de Lyon Bastille</a>'],
#      'photo_reference': 'Aap_uEDADl3sbs_yXRQESa9fbhSbTGRfWOG8I01eF2rJ96rf99rSTXO0m4lOEgxF54UQOORUbwg3pC92EBAPgy6ckQpG0Viy48lGXpDXdgR-t3vux9RUwyixtf84D1YLf0ITn_1sDpSfMUXChn-GGsLHT6t_ioSQiGAtoZwBxWs9QCgZsbbH',
#      'width': 1181}],
#    'place_id': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'plus_code': {'compound_code': 'R9XC+2P Paris, France',
#     'global_code': '8FW4R9XC+2P'},
#    'rating': 3.3,
#    'reference': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 381,
#    'vicinity': '12 Rue de Lyon, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8717386, 'lng': 2.3447052},
#     'viewport': {'northeast': {'lat': 48.8731374802915,
#       'lng': 2.346059980291502},
#      'southwest': {'lat': 48.8704395197085, 'lng': 2.343362019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Prélude Opéra Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113098608949799179620">Chrystelle Baudry</a>'],
#      'photo_reference': 'Aap_uEAlf7ew6m8M2EWsVhcQHLbXQolH6YI4fGKP_kRrzYdz9qaQ7d7hTy0Pmu1RqnfUhF2PvQbT54Fnr8IxSQNcAGX_Qf4pJ9Y2hzKdvzi54MIqXg9ZvJOrPpZ85QIe-OvkBkDkcB5KVwu13eWirc6Q1R5ntXvH4JuFGtbnEySXR5yvrtkJ',
#      'width': 3840}],
#    'place_id': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'plus_code': {'compound_code': 'V8CV+MV Paris, France',
#     'global_code': '8FW4V8CV+MV'},
#    'rating': 4.2,
#    'reference': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 368,
#    'vicinity': '8 Cité Bergère, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8423491, 'lng': 2.3632246},
#     'viewport': {'northeast': {'lat': 48.84365908029149,
#       'lng': 2.364711430291502},
#      'southwest': {'lat': 48.8409611197085, 'lng': 2.362013469708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Libertel Austerlitz Jardin des Plantes',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114802271282641766772">Hôtel Libertel Austerlitz Jardin des Plantes</a>'],
#      'photo_reference': 'Aap_uEA3Il-4vJ9m6AyFHzCSQxEf7WPW9ajdP0RO4vylShDUT5MVMQnDxF711GwHUhnOa-rUFuY0nC4IXkwXlnrkw41WFxGzfbzA5dTi41ZfcNkrZjlDwuOGCo289f5BEoa8raD0o11V7UlLf5jjBy5A1X0plTXUC1rJYPYgTUqiQFLXWaQ_',
#      'width': 6720}],
#    'place_id': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'plus_code': {'compound_code': 'R9R7+W7 Paris, France',
#     'global_code': '8FW4R9R7+W7'},
#    'rating': 4,
#    'reference': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 436,
#    'vicinity': "12 Boulevard de l'Hôpital, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8642974, 'lng': 2.3308142},
#     'viewport': {'northeast': {'lat': 48.8655789302915,
#       'lng': 2.332153980291502},
#      'southwest': {'lat': 48.8628809697085, 'lng': 2.329456019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Saint James Albany Paris Hôtel Spa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 844,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108570400659068256718">Saint James Albany Paris Hôtel Spa</a>'],
#      'photo_reference': 'Aap_uEBUkaXJtlAZmatgE-XGbXlU5x8VpMI2lxFgjuVhhu2f7u4S7CcsidGecyHwrHtJl4TNbcEEFud61M96CyoWs7aHgqmbi6B1iw0iLDpR1V9kk1fWsl-kWgfGKrGISwOHkROpsH7dQq0dv2yCcS8kHHPp5mTmZQ07_JXBsKOoROn8KyKq',
#      'width': 1500}],
#    'place_id': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'plus_code': {'compound_code': 'V87J+P8 Paris, France',
#     'global_code': '8FW4V87J+P8'},
#    'rating': 4,
#    'reference': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1075,
#    'vicinity': '202 Rue de Rivoli, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.87110329999999, 'lng': 2.3389728},
#     'viewport': {'northeast': {'lat': 48.8724588802915,
#       'lng': 2.340112930291502},
#      'southwest': {'lat': 48.8697609197085, 'lng': 2.337414969708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Icône',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1066,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108137830440312077288">Hôtel Icône</a>'],
#      'photo_reference': 'Aap_uED5r6V6vfHugsYAzBiBZRVAXdyL0hwTYabCDt3dQkegSpYMdltx_JvWe5BGQ5f4jahaAUuHRTbiVWVUZNdm2Nls96CG2kc5MklMjh9fR3kG2jz0q-CI_3fnso9TAZiGrhAE3FBThlQi8phLDEGrhIVHNg-zTBzMaCRDtdogwR8ZBKVU',
#      'width': 1600}],
#    'place_id': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'plus_code': {'compound_code': 'V8CQ+CH Paris, France',
#     'global_code': '8FW4V8CQ+CH'},
#    'rating': 3.7,
#    'reference': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 139,
#    'vicinity': "4 Rue d'Amboise, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.8538838802915,
#       'lng': 2.348601530291502},
#      'southwest': {'lat': 48.8511859197085, 'lng': 2.345903569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106443224837840180239">Fraz A. Khan</a>'],
#      'photo_reference': 'Aap_uECUhewrRusjykbWhU_AuNbo8pSGB87qceAEaqmzUXXUeBAplFETPhFxERdsMsHPVO-gl1bi1DcCZyhM2hrfHzMWDV8gSbOAVS-7y3atSCKMeXp9GsyhisCgr6wlm67yZtC_3-kIvfd0MoGm_fZ8MehmFEZnbYWgIIuBrGpF6zvsuLH2',
#      'width': 4032}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 145,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544403302915,
#       'lng': 2.346001280291502},
#      'southwest': {'lat': 48.8517423697085, 'lng': 2.343303319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'Aap_uEDPEfmDYuytOJDunu62YMoIco4y8822Q7AkhyDk0UryG4vKEcB9CJSX5pLwxxcEQj2epZd2TgzLqrykXbWdQhQQybgQB-iUNAhqb26UFuaqFLy1t15Ph_roiU2g8hnlY253uhX7AYRm3-ndxis5XmQaaYjxQFWdwUhzLtCAA9IETRhI',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 328,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8499443, 'lng': 2.3462474},
#     'viewport': {'northeast': {'lat': 48.8512737302915,
#       'lng': 2.347507380291502},
#      'southwest': {'lat': 48.8485757697085, 'lng': 2.344809419708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Home Latin',
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108547915404801536469">Jp Homma</a>'],
#      'photo_reference': 'Aap_uEB1HbcKzHJTJPT4JbtieXr8lIypijgGFb9Gm8iXLAQEdWfPnrTpdUBTVxGPMy91l6Ob0OLajwxSqpyz4NZKUrlKhowT2kNOLClIaqXd802HYQQLf2_O6PVrhhpsuQDDMvTMNVwmbZc_-Z_wjmojhsHlLUD8aa6264_UrymNVtmiBiX0',
#      'width': 4608}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.6,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 276,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85473870000001, 'lng': 2.3395455},
#     'viewport': {'northeast': {'lat': 48.8561127802915,
#       'lng': 2.340820530291502},
#      'southwest': {'lat': 48.8534148197085, 'lng': 2.338122569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Hôtel d'Aubusson",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3568,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115702439863948549296">Hôtel d&#39;Aubusson Paris</a>'],
#      'photo_reference': 'Aap_uECUeECnC4WVOZPA37CWqD68x0auXxGDblL9yLeG-_0iQSva3d1XHCtroWMhKSZvkADOcSGp_xmdi6paP3FqWILgYXSTnTnW37cdulS9o4whDytIZjoNcfW533rKHVNFQl2mkkZbV5R-KfBCC8Zu0Rfxd0DxDrZwz4HE0e5u4YZtRJ4v',
#      'width': 5353}],
#    'place_id': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'plus_code': {'compound_code': 'V83Q+VR Paris, France',
#     'global_code': '8FW4V83Q+VR'},
#    'rating': 4.7,
#    'reference': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 291,
#    'vicinity': '33 Rue Dauphine, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.8531470802915,
#       'lng': 2.346121880291502},
#      'southwest': {'lat': 48.8504491197085, 'lng': 2.343423919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'Aap_uEB3vT1fRnKv1KrKxYGpoyTa8wnQfh9Ebhdivke2SdHkVkfQdo2frhHM-DAFNB7-GiTcyAEv0rb7cjaG-Tw4ou5UO77RrOD6riDN3Qb8uZ-IBECRxh0mYtF4VlJSigPPusRk44nkmR_r-XCdPjOBHlb7DSfVOSOab-2TybfwX0Gsvj-U',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 139,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'}],
#  'status': 'OK'}

# %%
hotels['results'][0]['name']
# Out:
# 'Hôtel Duo'

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        
        print('Hotel for ' + hotel_df.loc[index, 'City'] + ' is: ' + hotel_df.loc[index, "Hotel Name"])
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel for Arraial Do Cabo is: Pousada Porto Praia
# Hotel not found... skipping.
# Hotel for Sterling is: Hampton Inn & Suites Washington-Dulles International Airport
# Hotel for Beihai is: 21 Degree Hostel
# Hotel for Hilo is: Hilo Hawaiian Hotel
# Hotel for Bethel is: Courtyard by Marriott Danbury
# Hotel for Dehloran is: کافه گیم استورم
# Hotel for Sheboygan is: Baymont by Wyndham Plymouth
# Hotel for Biak is: Penginapan Kim
# Hotel for Meulaboh is: Kost Pria
# Hotel for Saint George is: Best Western Plus Abbey Inn
# Hotel for Nchelenge is: KD Travellers Home
# Hotel for Pinehurst is: SpringHill Suites by Marriott Pinehurst Southern Pines
# Hotel for Labuhan is: PT PPI Lamongan Tambak C
# Hotel for Faanui is: Bora-Bora Pearl Beach Resort & Spa
# Hotel for Puerto Ayora is: Finch Bay Galapagos Hotel
# Hotel for Denpasar is: ASTON Denpasar Hotel & Convention Center
# Hotel for San Ignacio is: Rainforest Haven Inn
# Hotel for Port Said is: Aracan Hotel
# Hotel for Gat is: OlusHome
# Hotel for Atuona is: Villa Enata
# Hotel for Laguna is: Holiday Inn Express & Suites Elk Grove Central - Hwy 99, an IHG Hotel
# Hotel for Kutum is: Dibbo areaمنطقة دبو
# Hotel for Naze is: オーベルジュ・アガルイ
# Hotel for Riyadh is: InterContinental Riyadh, an IHG Hotel
# Hotel for Jamestown is: Hampton Inn & Suites Jamestown
# Hotel for Singaraja is: Puri Bagus Lovina Resort
# Hotel for Hithadhoo is: Scoop Guest House
# Hotel for Tecoanapa is: Hotel Manglares
# Hotel for Owensboro is: Courtyard by Marriott Owensboro
# Hotel for Jaggayyapeta is: A P S Resorts & Hotels Pvt Ltd
# Hotel for Batticaloa is: Grand Star Guest House
# Hotel for Georgetown is: Cititel Penang
# Hotel for Chikwawa is: Thawale Lodge
# Hotel for Port Blair is: Welcomhotel By ITC Hotels, Bay Island, Port Blair
# Hotel for Sumter is: Paradise Oaks RV Resort
# Hotel for Butaritari is: Isles Sunset Lodge
# Hotel for Castro is: CHACARA BAILLY
# Hotel for Sao Filipe is: Hotel Xaguate
# Hotel for Auki is: Auki Motel
# Hotel for Trairi is: janelas do mar
# Hotel for Roma is: Wingate By Wyndham Rome
# Hotel for High Rock is: Hideaway Bahamas Beach Club
# Hotel for Nhulunbuy is: East Arnhem Real Estate
# Hotel for Kloulklubed is: Storyboard Beach Resort
# Hotel for Vanimo is: Vahmoneh Lodge Vanimo
# Hotel for Nanakuli is: Camp Pālehua
# Hotel for Belmonte is: Pousada Monte Carmelo O Pão
# Hotel for Kapaa is: Sheraton Kauai Coconut Beach Resort
# Hotel for Kalemie is: Mahobilali
# Hotel for Kahului is: Maui Seaside Hotel
# Hotel not found... skipping.
# Hotel for Ponta Do Sol is: Hotel do Campo
# Hotel for Paita is: Hotel Náutico de Paita
# Hotel for Namatanai is: Seagulls Inn Namatani
# Hotel for Itoman is: Southern Beach Hotel & Resort Okinawa
# Hotel for Axim is: Axim Beach Resort And Spa
# Hotel for Imbituba is: Praia Hotel Imbituba
# Hotel for Victoria is: Mini Hotel Central
# Hotel for Dunn is: Cedar Falls Acres
# Hotel for Kupang is: Hotel On The Rock by Prasanthi
# Hotel for Kimbe is: Kimbe Bay Hotel
# Hotel for Rundu is: Millennia Estate
# Hotel for Cabinda is: Hotel Maiombe
# Hotel for Pochutla is: Hotel Posada San Jose
# Hotel for Amalapuram is: swayamprabha service apartments
# Hotel for Laem Sing is: Laemsing Whitehouse Resort
# Hotel for Kavieng is: Nusa Island Retreat
# Hotel for Sola is: Leumerus Bungalows
# Hotel for Salalah is: HAMDAN PLAZA HOTEL SALALAH
# Hotel for Vila Velha is: Quality Suites Vila Velha
# Hotel for Kailua is: Sheffield House Bed & Breakfast
# Hotel for Russell is: Macs
# Hotel for San Cristobal is: Posada Villaven C.A.
# Hotel for Takoradi is: Raybow International Hotel
# Hotel for Eravur is: Farhan KING House
# Hotel for Bengkulu is: Grage Hotel Bengkulu
# Hotel for Metro is: OYO 3177 Wisma Lintang
# Hotel for Khagaul is: Hotel FrontLine Residency
# Hotel for Terenos is: Rancho Pitzer
# Hotel for Kavaratti is: Hotels in Lakshadweep Islands
# Hotel for Pemex is: Hotel Alquimia Premier
# Hotel for Tacoronte is: Casa Laurel
# Hotel for Wenling is: Hanting Express Wenling Wanchang North Road
# Hotel for Isla Mujeres is: Hotel La Joya Isla Mujeres
# Hotel for Tevaitoa is: Hôtel Raiatea Lodge
# Hotel for Sao Jose Da Coroa Grande is: Crôa Mares Hotel
# Hotel for Touros is: INN NEW HORIZON
# Hotel for Pinheiro Machado is: Hotel e Restaurante Quitandinha
# Hotel for Silopi is: Özenler Residence Otel, Şırnak Silopi
# Hotel for Houma is: Courtyard by Marriott Houma
# Hotel for Umm Lajj is: Moon light Furnished Units
# Hotel for Buchanan is: Kamaneahn Hotel Inc
# Hotel for Linhares is: Hotel Conceição
# Hotel not found... skipping.
# Hotel for Inhambane is: Oceano
# Hotel for Tukrah is: Lagrota restaurant
# Hotel for Susangerd is: دفتر خدمات هوایی وجهانگردی نسیم گستر دشت آزادگان
# Hotel for Buala is: Maringe Lagoon Lodge
# Hotel for Robertsport is: Kwepunha Retreat
# Hotel for Richards Bay is: BON Hotel Waterfront Richards Bay
# Hotel for Makakilo City is: Marriott's Ko Olina Beach Club
# Hotel for Olinda is: Hotel Albergue de Olinda
# Hotel for Blackfoot is: Super 8 by Wyndham Blackfoot/Idaho Falls
# Hotel for Pasighat is: Siang Guest House
# Hotel for Barcelona is: Axel Hotel Barcelona
# Hotel for Hobyo is: Halane Hotel and Restaurent
# Hotel for Carutapera is: Lidera
# Hotel for Ishigaki is: Hotel Peace Land Ishigakijima
# Hotel for Tagusao is: Toledo
# Hotel for Turbat is: Mubashar Quarters
# Hotel for Bloemfontein is: aha Bloemfontein Hotel
# Hotel for Shenjiamen is: Jinjiang Inn Zhoushan Putuo Shenjiamen
# Hotel not found... skipping.
# Hotel for Bandarbeyla is: JABIR HOTEL
# Hotel for Izmir is: Blue City Boutique Hotel
# Hotel for Tahta is: مصطفي عساف
# Hotel for Kattivakkam is: Euronova Freezer
# Hotel for Rio Grande is: Hotel Atlântico Rio Grande
# Hotel for Sokoto is: Shukura Coral Hotel
# Hotel for Sao Joao Da Barra is: Pousada Porto De Canoas
# Hotel for Wilmington is: Hotel Ballast Wilmington, Tapestry Collection by Hilton
# Hotel for Lazaro Cardenas is: quinta antigua
# Hotel for Bouna is: Hotel Reserve
# Hotel for Aquiraz is: Pousada Rua Camurupim
# Hotel for Los Llanos De Aridane is: Valle Aridane
# Hotel for Itarema is: Sea Lounge! Bar, Club & Restaurant
# Hotel for Broome is: Chenango Valley State Park
# Hotel not found... skipping.
# Hotel for Sabang is: Hotel Citra
# Hotel for Muskegon Heights is: Red Roof Inn & Suites Muskegon Heights
# Hotel for Tazmalt is: Hôtel Numédia
# Hotel for Mehriz is: Mehrgard dwelling/سرای مهرگرد
# Hotel for Hamilton is: Six Acres Bed & Breakfast
# Hotel for Koutsouras is: The White Houses
# Hotel for Mana is: LE SAMANA
# Hotel for Buraydah is: فندق راحة السلام
# Hotel for Dingle is: SEGAYA PROPERTY
# Hotel not found... skipping.
# Hotel for Celestun is: Posada Lilia
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel for Tabas is: شرکت معماری مهراز شایگان آراد
# Hotel for Mitsamiouli is: Foyer ADM
# Hotel for Price is: National 9 - Price River Inn
# Hotel for Bathsheba is: Atlantis Hotel
# Hotel for Nishihara is: Minshuku Agaihama
# Hotel for Coahuayana is: El rranchito michuacan de ocampos
# Hotel for Salina Cruz is: Amerik HOTEL
# Hotel for Matara is: Amaloh Boutique Resort
# Hotel not found... skipping.
# Hotel for Tutoia is: Pousada Guará's
# Hotel for Isabela is: Isawad Resort
# Hotel for Sorong is: waigo splash hotel
# Hotel for Morena is: Hotel Upkar Palace
# Hotel for Alta Floresta is: Floresta Amazonica Hotel
# Hotel for Puerto Ayacucho is: Posada Turistica Manapiare
# Hotel for Bonthe is: Bonthe Holiday Village
# Hotel for Khed Brahma is: UMIYA NASTA HOUSE
# Hotel for Tuy Hoa is: CenDeluxe Hotel Tuy Hoa
# Hotel for Bubaque is: Casa Dora, Bubaque
# Hotel for Riohacha is: Hotel Taroa
# Hotel for Panalingaan is: I Love Panalingaan View Deck
# Hotel for Kathu is: Novotel Phuket Resort
# Hotel for Mexico is: stone place
# Hotel for Vendas Novas is: Hotel Acez
# Hotel for Sur is: Sur Plaza Hotel
# Hotel for Ewo is: Residence Elonda Ewo
# Hotel for Moroni is: Hotel les Arcades
# Hotel for Birjand is: Birjand Tourist Hotel
# Hotel for Clarksville is: Riverview Inn
# Hotel for Jacqueville is: Hotel Le Martin Pecheur
# Hotel for Caravelas is: Pousada dos Navegantes
# Hotel for Sardarshahr is: Hotel Moti Mahal
# Hotel for Havelock is: Sherwood Motel
# Hotel for Nouakchott is: HOTEL IMAN فندق إيمان
# Hotel for Odweyne is: Eng Hiirey House
# Hotel for Belle Glade is: Mid-City Trailer Park
# Hotel not found... skipping.
# Hotel for Acapulco is: HS Hotsson Smart Acapulco
# Hotel for Gobabis is: Goba Lodge
# Hotel for Castanhal is: ESTAÇÃO HOTEL
# Hotel for La Peca is: Hospedaje San Miguelito
# Hotel not found... skipping.
# Hotel for Wanning is: Paradise Hotel
# Hotel for Dumka is: Hotel Shashwat , Sri Shyam Plaza ,Dumka
# Hotel for Sinnar is: هجو الطاهر
# Hotel for Bima is: Lambitu Hotel
# Hotel for Honiara is: Heritage Park Hotel
# Hotel for Taylorville is: Economy Inn
# Hotel for Alice Springs is: Desert Palms Alice Springs
# Hotel for Pombas is: Paul Paradis
# Hotel for Colomi is: Casa
# Hotel for Padang is: Mercure Padang
# Hotel for Tiarei is: Le Rocher de Tahiti
# Hotel for Puerto Escondido is: Aldea del Bazar Hotel and Spa
# Hotel for Virginia Beach is: Hilton Virginia Beach Oceanfront
# Hotel for Ormara is: Crystal Beach and Camping Resort Ormara
# Hotel for Hirara is: Hotel Atoll Emerald Miyakojima
# Hotel for Utinga is: Espaço de Lazer Érica Fernandes
# Hotel for Mecca is: Makkah Clock Royal Tower, A Fairmont Hotel
# Hotel for Moyale is: La Tahzan Guest House
# Hotel for Kulhudhuffushi is: Hondaafushi Island Resort
# Hotel for Marsaxlokk is: Water's Edge
# Hotel for Nouadhibou is: El Medina
# Hotel for Springfield is: University Plaza Hotel & Convention Center
# Hotel for Salinopolis is: Salinas Park Resort Maçarico AP101
# Hotel for Minab is: Bam campground

# %%
hotel_df.head()
# Out:
#                City Country  Max Temp      Lat       Lng  \
# 4   Arraial Do Cabo      BR     80.56 -22.9661  -42.0278
# 5            Albany      US     75.74  42.6001  -73.9662
# 8          Sterling      US     81.77  39.0062  -77.4286
# 10           Beihai      CN     83.62  21.4833  109.1000
# 11             Hilo      US     76.80  19.7297 -155.0900
#
#                                            Hotel Name
# 4                                 Pousada Porto Praia
# 5
# 8   Hampton Inn & Suites Washington-Dulles Interna...
# 10                                   21 Degree Hostel
# 11                                Hilo Hawaiian Hotel

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.6)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
